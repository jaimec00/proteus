# %% [markdown]
# # dataloader stuff
#
# ### for debugging the dataloader

# %%
from proteus.data.data_loader import DataHolder, DataHolderCfg
import logging
logging.basicConfig(level=logging.INFO)

cfg = DataHolderCfg(
    s3_bucket="s3://proteus-data-bucket",
    cluster_split_cols=["foldseek_70", "mmseqs_30"],
    cluster_col="foldseek_70"
)

data_holder = DataHolder(cfg)
# Out:
# INFO:botocore.credentials:Found credentials from IAM Role: S3
# INFO:botocore.credentials:Found credentials from IAM Role: S3
# INFO:proteus.data.data_loader:raw index contains 275 samples and 167 clusters
# INFO:proteus.data.data_loader:filtered index contains 275 samples and 167 clusters
# INFO:proteus.data.data_loader:raw train index contains 187 samples and 91 clusters
# INFO:proteus.data.data_loader:raw val index contains 4 samples and 2 clusters
# INFO:proteus.data.data_loader:raw test index contains 8 samples and 6 clusters
# INFO:proteus.data.data_loader:final train index contains 187 samples and 91 clusters
# INFO:proteus.data.data_loader:final val index contains 4 samples and 2 clusters
# INFO:proteus.data.data_loader:final test index contains 8 samples and 6 clusters
# INFO:proteus.data.data_loader:
# train:
#   target percentage: 90.00%
#   samples percentage: 93.97%
#   clusters percentage: 91.92%
#
# INFO:proteus.data.data_loader:
# val:
#   target percentage: 5.00%
#   samples percentage: 2.01%
#   clusters percentage: 2.02%
#
# INFO:proteus.data.data_loader:
# test:
#   target percentage: 5.00%
#   samples percentage: 4.02%
#   clusters percentage: 6.06%
